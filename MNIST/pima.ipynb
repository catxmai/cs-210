# %%
import pandas as pd
import statistics

# 1. Number of times pregnant
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3. Diastolic blood pressure (mm Hg)
# 4. Triceps skin fold thickness (mm)
# 5. 2-Hour serum insulin (mu U/ml)
# 6. Body mass index (weight in kg/(height in m)^2)
# 7. Diabetes pedigree function
# 8. Age (years)
# 9. Class variable (0 or 1)

data = pd.read_csv("pima.txt", sep=",", header=None)

for col in range(0,len(data.columns)):
    print("COLUMN "+ str(col+1))
    print("Variance:  " + str(statistics.variance(data[col])))
    print(data[col].describe())
# Out:
# COLUMN 1
# Variance:  11.354056320621469
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: 0, dtype: float64
# COLUMN 2
# Variance:  1022.2483142519557
# count    768.000000
# mean     120.894531
# std       31.972618
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: 1, dtype: float64
# COLUMN 3
# Variance:  374.6472712271838
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: 2, dtype: float64
# COLUMN 4
# Variance:  254.47324532811822
# count    768.000000
# mean      20.536458
# std       15.952218
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: 3, dtype: float64
# COLUMN 5
# Variance:  13281.180077955236
# count    768.000000
# mean      79.799479
# std      115.244002
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      846.000000
# Name: 4, dtype: float64
# COLUMN 6
# Variance:  62.15998395738266
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: 5, dtype: float64
# COLUMN 7
# Variance:  0.10977863787313939
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: 6, dtype: float64
# COLUMN 8
# Variance:  138.30304589037374
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: 7, dtype: float64
# COLUMN 9
# Variance:  0.22748261625380273
# count    768.000000
# mean       0.348958
# std        0.476951
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: 8, dtype: float64
